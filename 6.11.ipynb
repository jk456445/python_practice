# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
X =np.random.rand(100,2)

# %%
X[0]
# Out:
# array([0.33536504, 0.33279892])

# %%
plt.scatter(X[:,0], X[:,1],s=50)

# %%
from sklearn.cluster import KMeans

# %%
clf=KMeans(n_clusters=3) #開一個KMeans機器，然後要分3群

# %%
clf.fit(X)
# Out:
# KMeans(n_clusters=3)

# %%
clf.labels_
# Out:
# array([2, 1, 1, 2, 0, 0, 0, 2, 0, 0, 1, 1, 2, 2, 1, 1, 1, 0, 1, 0, 1, 1,
#        1, 1, 0, 2, 0, 2, 2, 2, 0, 1, 0, 1, 2, 0, 2, 1, 0, 0, 1, 2, 1, 0,
#        1, 1, 1, 0, 0, 2, 1, 1, 0, 0, 1, 0, 1, 1, 2, 0, 2, 1, 0, 2, 0, 2,
#        1, 2, 1, 2, 2, 1, 0, 2, 2, 2, 0, 0, 1, 1, 2, 1, 2, 2, 1, 2, 1, 2,
#        1, 2, 0, 0, 0, 2, 0, 2, 2, 1, 2, 1])

# %%
plt.scatter(X[:,0],X[:,1], c=clf.labels_)
